# %%
# install Pint if necessary
try:
    from pint import UnitRegistry
except ImportError:
    # !pip install pint

# %%
# download modsim.py if necessary

from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve
        local, _ = urlretrieve(url, filename)
        print('Downloaded ' + local)
    
download('https://github.com/AllenDowney/ModSimPy/raw/master/' +
         'modsim.py')

# %%
# import libraries

from modsim import *
import numpy
import pandas as pd

# %%
df = pd.read_csv('sample/suicide-rates-among-young-people.csv')
#df.tail()
#df.head()
#df.info()
#df
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  2000
# 1     Afghanistan  AFG  2001
# 2     Afghanistan  AFG  2002
# 3     Afghanistan  AFG  2003
# 4     Afghanistan  AFG  2004
# ...           ...  ...   ...
# 3795     Zimbabwe  ZWE  2015
# 3796     Zimbabwe  ZWE  2016
# 3797     Zimbabwe  ZWE  2017
# 3798     Zimbabwe  ZWE  2018
# 3799     Zimbabwe  ZWE  2019
#
#       Death rate per 100,000 people - Cause: Self-harm - Sex: Both sexes - Age group: YEARS15-19  \
# 0                                              5.773377
# 1                                              6.127417
# 2                                              5.736194
# 3                                              5.589899
# 4                                              5.629840
# ...                                                 ...
# 3795                                          10.232885
# 3796                                           9.983424
# 3797                                           9.773547
# 3798                                           9.672438
# 3799                                           9.739059
#
#       Death rate per 100,000 people - Cause: Self-harm - Sex: Both sexes - Age group: YEARS20-24  \
# 0                                              8.977578
# 1                                              9.883379
# 2                                              9.926080
# 3                                              9.757331
# 4                                             10.310462
# ...                                                 ...
# 3795                                          13.056926
# 3796                                          12.505952
# 3797                                          12.217892
# 3798                                          11.963584
# 3799                                          11.731317
#
#       Death rate per 100,000 people - Cause: Self-harm - Sex: Both sexes - Age group: YEARS25-34
# 0                                             10.135592
# 1                                             10.808245
# 2                                             10.616271
# 3                                             10.216901
# 4                                             10.593060
# ...                                                 ...
# 3795                                          17.767336
# 3796                                          15.922534
# 3797                                          13.057365
# 3798                                          12.868393
# 3799                                          12.919739
#
# [3800 rows x 6 columns]

# %%
df_filtered = df[(df['Year'] >= 2000) & (df['Year'] <= 2019)]
df_sorted = df_filtered.sort_values(by=['Entity', 'Year'])

# %%
df_grouped = df_filtered.groupby(['Entity', 'Year']).agg({
    'Death rate per 100,000 people - Cause: Self-harm - Sex: Both sexes - Age group: YEARS15-19': 'mean',
    'Death rate per 100,000 people - Cause: Self-harm - Sex: Both sexes - Age group: YEARS20-24': 'mean',
    'Death rate per 100,000 people - Cause: Self-harm - Sex: Both sexes - Age group: YEARS25-34': 'mean'
}).reset_index()

# %%
# Tes count by country
changes = {}
for column in df_grouped.columns[2:]:
    changes[column] = df_grouped[column].diff().tolist()
    for entity in df_grouped['Entity'].unique():
        entity_min_year = df_grouped[df_grouped['Entity'] == entity]['Year'].min()
        if entity_min_year == 2000:
            entity_indices = df_grouped.index[df_grouped['Entity'] == entity]
            changes[column][entity_indices[0]] = 0

# %%
# Tes count by country
df_changes = pd.DataFrame(changes)
df_changes['Entity'] = df_grouped['Entity']
print(df_changes[0:60])

# %%
# count all
total_changes = {str(year): 0 for year in range(2001, 2020)}

# Menambahkan nilai perubahan untuk setiap tahun dari seluruh negara
for column in df_grouped.columns[2:]:
    for i, year in enumerate(range(2001, 2020)):
        total_changes[str(year)] += sum(df_grouped[column][df_grouped['Year'] == year])

# Menghitung rata-rata perubahan untuk setiap tahun
mean_changes = {year: total_change / len(df_grouped['Entity'].unique()) for year, total_change in total_changes.items()}

# Menampilkan hasil
print("Rata-rata kenaikan angka kematian untuk seluruh dunia dari tahun 2000 hingga 2019:")
for year, mean_change in mean_changes.items():
    print(f"Tahun {year}: {mean_change}")
# Out:
# Rata-rata kenaikan angka kematian untuk seluruh dunia dari tahun 2000 hingga 2019:
# Tahun 2001: 34.352040577578954
# Tahun 2002: 33.80081593157895
# Tahun 2003: 32.992253363
# Tahun 2004: 32.71440395121052
# Tahun 2005: 32.72790711178948
# Tahun 2006: 31.929876232105254
# Tahun 2007: 31.69747067210527
# Tahun 2008: 31.528081573684204
# Tahun 2009: 31.522357505368415
# Tahun 2010: 30.839928094947357
# Tahun 2011: 30.39166126842104
# Tahun 2012: 30.230747070999993
# Tahun 2013: 29.456738229421045
# Tahun 2014: 29.116216235421042
# Tahun 2015: 28.395410333473677
# Tahun 2016: 27.408431266315798
# Tahun 2017: 27.365036767789473
# Tahun 2018: 26.49786290663159
# Tahun 2019: 26.09063531894736

# %%
df_grouped
# Out:
#            Entity  Year  \
# 0     Afghanistan  2000
# 1     Afghanistan  2001
# 2     Afghanistan  2002
# 3     Afghanistan  2003
# 4     Afghanistan  2004
# ...           ...   ...
# 3795     Zimbabwe  2015
# 3796     Zimbabwe  2016
# 3797     Zimbabwe  2017
# 3798     Zimbabwe  2018
# 3799     Zimbabwe  2019
#
#       Death rate per 100,000 people - Cause: Self-harm - Sex: Both sexes - Age group: YEARS15-19  \
# 0                                              5.773377
# 1                                              6.127417
# 2                                              5.736194
# 3                                              5.589899
# 4                                              5.629840
# ...                                                 ...
# 3795                                          10.232885
# 3796                                           9.983424
# 3797                                           9.773547
# 3798                                           9.672438
# 3799                                           9.739059
#
#       Death rate per 100,000 people - Cause: Self-harm - Sex: Both sexes - Age group: YEARS20-24  \
# 0                                              8.977578
# 1                                              9.883379
# 2                                              9.926080
# 3                                              9.757331
# 4                                             10.310462
# ...                                                 ...
# 3795                                          13.056926
# 3796                                          12.505952
# 3797                                          12.217892
# 3798                                          11.963584
# 3799                                          11.731317
#
#       Death rate per 100,000 people - Cause: Self-harm - Sex: Both sexes - Age group: YEARS25-34
# 0                                             10.135592
# 1                                             10.808245
# 2                                             10.616271
# 3                                             10.216901
# 4                                             10.593060
# ...                                                 ...
# 3795                                          17.767336
# 3796                                          15.922534
# 3797                                          13.057365
# 3798                                          12.868393
# 3799                                          12.919739
#
# [3800 rows x 5 columns]
